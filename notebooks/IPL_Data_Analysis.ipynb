# %%
import  pandas as pd
import numpy as np

# %%
ipl = pd.read_csv('../datasets/matches.csv')

# %% [markdown]
# ### use some functions

# %%
ipl.size
# Out:
# 21900

# %%
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
ipl.sample(3)
# Out:
#          id   season        city        date match_type player_of_match  \
# 165  419156  2009/10  Dharamsala  2010-04-16     League       RG Sharma
# 467  829725     2015        Pune  2015-04-15     League      MA Agarwal
# 276  548335     2012     Cuttack  2012-04-22     League           B Lee
#
#                                             venue            team1  \
# 165  Himachal Pradesh Cricket Association Stadium  Kings XI Punjab
# 467       Maharashtra Cricket Association Stadium  Kings XI Punjab
# 276                              Barabati Stadium  Deccan Chargers
#
#                      team2            toss_winner toss_decision  \
# 165        Deccan Chargers        Deccan Chargers         field
# 467       Delhi Daredevils        Kings XI Punjab           bat
# 276  Kolkata Knight Riders  Kolkata Knight Riders         field
#
#                     winner   result  result_margin  target_runs  target_overs  \
# ...

# %%
ipl.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
ipl.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
ipl['id'].is_unique
# Out:
# True

# %%
ipl['id']=ipl.id.astype('int32')

# %%
ipl.set_index('id',inplace=True)

# %%
ipl
# Out:
#           season        city        date   match_type  player_of_match  \
# id
# 335982   2007/08   Bangalore  2008-04-18       League      BB McCullum
# 335983   2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 335984   2007/08       Delhi  2008-04-19       League      MF Maharoof
# 335985   2007/08      Mumbai  2008-04-20       League       MV Boucher
# 335986   2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...          ...         ...         ...          ...              ...
# 1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
#                                                      venue  \
# id
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1095 entries, 335982 to 1426312
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           1095 non-null   object
#  1   city             1044 non-null   object
#  2   date             1095 non-null   object
#  3   match_type       1095 non-null   object
#  4   player_of_match  1090 non-null   object
#  5   venue            1095 non-null   object
#  6   team1            1095 non-null   object
#  7   team2            1095 non-null   object
#  8   toss_winner      1095 non-null   object
#  9   toss_decision    1095 non-null   object
#  10  winner           1090 non-null   object
#  11  result           1095 non-null   object
#  12  result_margin    1076 non-null   float64
#  13  target_runs      1092 non-null   float64
#  14  target_overs     1092 non-null   float64
#  15  super_over       1095 non-null   object
# ...

# %% [markdown]
# #### Working with nan values

# %%
ipl.isnull().sum()
# Out:
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
ipl['city'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\kmoha\AppData\Local\Temp\ipykernel_10112\2099943219.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ipl['city'].fillna('Unknown', inplace=True)

# %%
ipl.isnull().sum()
# Out:
# season                0
# city                  0
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %% [markdown]
# ### Working with datatypes

# %%
ipl.dtypes
# Out:
# season              object
# city                object
# date                object
# match_type          object
# player_of_match     object
# venue               object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# target_runs        float64
# target_overs       float64
# super_over          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
ipl['season'] = ipl['season'].str.split('/').str[0]

# %%
ipl['date'] = pd.to_datetime(ipl['date'], errors='coerce')

# %%
ipl.team1 = ipl['team1'].astype('category')
ipl.team2 = ipl['team2'].astype('category')
ipl.toss_winner = ipl['toss_winner'].astype('category')
ipl.toss_decision = ipl['toss_decision'].astype('category')
ipl.match_type = ipl['match_type'].astype('category')
ipl.season = ipl['season'].astype('category')
ipl.venue = ipl['venue'].astype('category')
ipl.city = ipl['city'].astype('category')
ipl.player_of_match = ipl['player_of_match'].astype('category')

# %%
ipl.size
# Out:
# 20805

# %%
ipl.to_csv('../datasets/matches_clean.csv', index=False)
